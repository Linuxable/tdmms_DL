# %% [markdown]
# **Load Python Files**

# %%
import sys
sys.path.append('/content/drive/MyDrive/Delft/BEP')
sys.path.append('/content/tdmms_DL')

# !git clone https://github.com/Linuxable/tdmms_DL.git

# %% [markdown]
# **Imports**

# %%
from bep_training import train_model

# %% [markdown]
# **Config**

# %%
ROOT_DIR = '\\content\\drive\\MyDrive\\Delft\\BEP'

# %% [markdown]
# **Train**

# %%
train_model(ROOT_DIR)
